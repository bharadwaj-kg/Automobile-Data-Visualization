# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
df=pd.read_csv('Automobile.csv')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %%
sns.relplot(x='engine_size',y='price', data=df)

# %%
sns.relplot(x='engine_size',y='price',hue='horsepower',data=df)

# %%
sns.relplot(x='engine_size',y='price',hue='fuel_type', data=df)

# %%
sns.catplot(x='fuel_type',y='price',data=df)

# %%
sns.catplot(x='fuel_type',y='price', jitter=False,data=df)

# %%
sns.catplot(x='fuel_type',y='price',hue='symboling',data=df)

# %%
sns.catplot(x='fuel_type',y='price',kind='swarm',data=df)

# %%
sns.catplot(x='fuel_type',y='price',hue='symboling',kind='swarm', data=df)

# %%
sns.catplot(x='fuel_type',y='price',kind='box',data=df) #outliers for gas

# %%
df.describe(include='all')
# Out:
#          symboling  normalized_losses    make fuel_type aspiration  \
# count   201.000000         201.000000     201       201        201
# unique         NaN                NaN      22         2          2
# top            NaN                NaN  toyota       gas        std
# freq           NaN                NaN      32       181        165
# mean      0.840796         125.189055     NaN       NaN        NaN
# std       1.254802          33.572966     NaN       NaN        NaN
# min      -2.000000          65.000000     NaN       NaN        NaN
# 25%       0.000000         101.000000     NaN       NaN        NaN
# 50%       1.000000         122.000000     NaN       NaN        NaN
# 75%       2.000000         150.000000     NaN       NaN        NaN
# max       3.000000         256.000000     NaN       NaN        NaN
#
#        number_of_doors body_style drive_wheels engine_location  wheel_base  \
# count              201        201          201             201  201.000000
# ...

# %%
sns.catplot(x='fuel_type',y='price',hue='fuel_system',kind='box', data=df)

# %%
sns.catplot(x='fuel_type',y='price',hue='engine_location',kind='bar', data=df) #Inf:rear engine has high price.
#only gas systems has rear engine location.

# %%
sns.catplot(x='fuel_type',y='price',hue='drive_wheels',kind='point', data=df)

# %%
sns.catplot(x='fuel_type',y='price',hue='aspiration',col='drive_wheels', kind='swarm', data=df)
#Inf:4wd drive_wheels absent in Diesel systems. Majority of diesel systems are turbo. low prices are available at fwd drive wheels
# with gas systems.

# %%
sns.distplot(df.horsepower) #how horsepower is distributed across data. Kernal density estimate.

# %%
sns.distplot(df.normalized_losses,kde=False, rug= True)

# %%
sns.pairplot(df)

# %%
df.describe(include='all')
# Out:
#          symboling  normalized_losses    make fuel_type aspiration  \
# count   201.000000         201.000000     201       201        201
# unique         NaN                NaN      22         2          2
# top            NaN                NaN  toyota       gas        std
# freq           NaN                NaN      32       181        165
# mean      0.840796         125.189055     NaN       NaN        NaN
# std       1.254802          33.572966     NaN       NaN        NaN
# min      -2.000000          65.000000     NaN       NaN        NaN
# 25%       0.000000         101.000000     NaN       NaN        NaN
# 50%       1.000000         122.000000     NaN       NaN        NaN
# 75%       2.000000         150.000000     NaN       NaN        NaN
# max       3.000000         256.000000     NaN       NaN        NaN
#
#        number_of_doors body_style drive_wheels engine_location  wheel_base  \
# count              201        201          201             201  201.000000
# ...

# %%
pd.pivot_table(df, index=["make",'fuel_type'],
                     columns=['aspiration']) #We get mean as default.
# Out:
#                              bore          city_mpg             \
# aspiration                    std  turbo        std      turbo
# make          fuel_type
# alfa-romero   gas        3.206667    NaN  20.333333        NaN
# audi          gas        3.190000  3.130  19.800000  17.000000
# bmw           gas        3.473750    NaN  19.375000        NaN
# chevrolet     gas        2.990000    NaN  41.000000        NaN
# dodge         gas        3.031667  3.220  30.833333  22.333333
# honda         gas        3.021538    NaN  30.384615        NaN
# isuzu         gas        3.370000    NaN  24.000000        NaN
# jaguar        gas        3.600000    NaN  14.333333        NaN
# mazda         diesel     3.410000    NaN  33.500000        NaN
#               gas        3.268667    NaN  24.666667        NaN
# mercedes-benz diesel          NaN  3.580        NaN  22.000000
#               gas        3.630000    NaN  15.000000        NaN
# ...

# %%
corr=df.corr()
corr
# Out:
#                    symboling  normalized_losses  wheel_base    length  \
# symboling           1.000000           0.474993   -0.535987 -0.365404
# normalized_losses   0.474993           1.000000    0.007815  0.103659
# wheel_base         -0.535987           0.007815    1.000000  0.876024
# length             -0.365404           0.103659    0.876024  1.000000
# width              -0.242423           0.153752    0.814507  0.857170
# height             -0.550160          -0.335476    0.590742  0.492063
# curb_weight        -0.233118           0.178547    0.782097  0.880665
# engine_size        -0.110581           0.174788    0.572027  0.685025
# bore               -0.146355           0.007498    0.495210  0.610324
# stroke              0.018373           0.062666    0.148239  0.116745
# compression_ratio  -0.182196          -0.120846    0.250313  0.159733
# horsepower          0.075287           0.276665    0.372607  0.577923
# ...

# %%
plt.figure(figsize = (14,10))
sns.heatmap(corr,annot=True)

# %%
#price is strongly positively correlated with engine size, curb weight & horsepower.
#stroke has weak correlations.
